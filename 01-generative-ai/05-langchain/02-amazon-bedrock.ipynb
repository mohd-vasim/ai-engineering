# %%
# !uv add langchain-aws

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.getenv("AWS_ACCESS_KEY_ID")
# Out:
# 'AKIAWTKJD7FWYMOK2UUO'

# %%
from langchain_aws import ChatBedrock, ChatBedrockConverse

# %%
llm = ChatBedrockConverse(
    model="google.gemma-3-12b-it"
)

# %%
llm.invoke("hello").content
# Out:
# 'Hello there! 😊 \n\nHow can I help you today?'

# %%
llm = ChatBedrockConverse(
    model="qwen.qwen3-vl-235b-a22b"
)

# %%
llm.invoke("hello").content
# Out:
# "Hello! 👋 How can I assist you today? Whether you have a question, need help with something, or just want to chat—I'm here for you! 😊"

# %%
llm = ChatBedrockConverse(
    model="google.gemma-3-27b-it"
)

# %%
llm.invoke("hello").content
# Out:
# "Hello there! 👋 \n\nHow can I help you today? Just let me know what you're thinking, or if you just wanted to say hi, that's perfectly fine too! \n\nI can:\n\n* **Answer questions:** About pretty much anything (though I'm better at some things than others!).\n* **Generate text:** Like stories, poems, articles, code, etc.\n* **Translate languages.**\n* **Summarize text.**\n* **Help you brainstorm ideas.**\n* **Just chat!**\n\n\n\n"

# %%
# llm = ChatBedrockConverse(
#     model="anthropic.claude-haiku-4-5-20251001-v1:0"
# )

# %%
llm.invoke("hello")
# Out:
# AIMessage(content="Hello there! 👋 \n\nHow can I help you today? Just let me know what you're thinking, or if you just wanted to say hi, that's perfectly fine too! \n\nI can:\n\n* **Answer questions:** About pretty much anything!\n* **Generate creative content:** Like stories, poems, code, scripts, musical pieces, email, letters, etc.\n* **Translate languages.**\n* **Summarize text.**\n* **Help you brainstorm.**\n* **Just chat!**\n\n\n\n", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '4d6e2fbf-9445-4173-8c5d-09781978f7e1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 15 Mar 2026 15:03:41 GMT', 'content-type': 'application/json', 'content-length': '629', 'connection': 'keep-alive', 'x-amzn-requestid': '4d6e2fbf-9445-4173-8c5d-09781978f7e1'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2061]}, 'model_provider': 'bedrock_converse', 'model_name': 'google.gemma-3-27b-it'}, id='lc_run--019cf206-30e8-7542-aba9-075a6be01163-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 109, 'total_tokens': 119, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
llm = ChatBedrockConverse(
    model="qwen.qwen3-next-80b-a3b"
)

# %%
llm.invoke("hello")
# Out:
# AIMessage(content="Hello! 😊 How can I help you today? Whether you have a question, need help with something, or just want to chat—I'm here for you!", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '0d83bd6f-da63-41e4-90b2-bdab3bddbebf', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 15 Mar 2026 15:03:44 GMT', 'content-type': 'application/json', 'content-length': '334', 'connection': 'keep-alive', 'x-amzn-requestid': '0d83bd6f-da63-41e4-90b2-bdab3bddbebf'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [906]}, 'model_provider': 'bedrock_converse', 'model_name': 'qwen.qwen3-next-80b-a3b'}, id='lc_run--019cf206-3c31-7c91-bfc8-4cc20e2add34-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 34, 'total_tokens': 43, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
llm.invoke("hi")
# Out:
# AIMessage(content="Hello! 😊 How can I help you today? Whether you have a question, need advice, or just want to chat—I'm here for you!", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'da88fec8-857f-4e9c-b030-2b75b61c5b9e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 15 Mar 2026 15:03:45 GMT', 'content-type': 'application/json', 'content-length': '321', 'connection': 'keep-alive', 'x-amzn-requestid': 'da88fec8-857f-4e9c-b030-2b75b61c5b9e'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [813]}, 'model_provider': 'bedrock_converse', 'model_name': 'qwen.qwen3-next-80b-a3b'}, id='lc_run--019cf206-44e4-7e80-8b6c-aae6b1237536-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 32, 'total_tokens': 41, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
llm.invoke("vasim")
# Out:
# AIMessage(content='Hello! It seems like you mentioned "vasim." Could you please clarify or provide more details? Are you referring to:\n\n- **Vasim** as a person\'s name?\n- **Vasim** as a place (e.g., Vasim in Maharashtra, India)?\n- Something else entirely?\n\nI’d be happy to help depending on what you mean! 😊', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'bf6b2547-a3fb-409b-8fc5-d6bb01ef5387', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 15 Mar 2026 15:03:58 GMT', 'content-type': 'application/json', 'content-length': '503', 'connection': 'keep-alive', 'x-amzn-requestid': 'bf6b2547-a3fb-409b-8fc5-d6bb01ef5387'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [1546]}, 'model_provider': 'bedrock_converse', 'model_name': 'qwen.qwen3-next-80b-a3b'}, id='lc_run--019cf206-7240-75b1-8993-9543ba17714d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 77, 'total_tokens': 87, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})
