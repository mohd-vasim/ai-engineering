# %% [markdown]
# <a href="https://colab.research.google.com/github/92-vasim/LLMs/blob/main/open-source-llms/llama-2/Llama2_langchain_llama_cpp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Setup**

# %%
# %%capture
# !pip install huggingface-hub hf-transfer langchain llama-cpp-python

# %%
# %%capture
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python

# %%
# !wget https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/llama-2-7b-chat.Q3_K_M.gguf

# %%
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# !huggingface-cli download \
#   Deci/DeciLM-7B-instruct-GGUF \
#   decilm-7b-uniform-gqa-q8_0.gguf \
#   --local-dir . \
#   --local-dir-use-symlinks False

REPO = "TheBloke/Llama-2-7B-Chat-GGUF"
MODEL_Q2 = "llama-2-7b-chat.Q2_K.gguf"
MODEL_Q4_M = "llama-2-7b-chat.Q4_K_M.gguf"

# !huggingface-cli download \
  $REPO \
   $MODEL_Q4_M\
  --local-dir . \
  --local-dir-use-symlinks False
# Out:
# downloading https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/llama-2-7b-chat.Q4_K_M.gguf to /root/.cache/huggingface/hub/tmpkghiimv4
# llama-2-7b-chat.Q4_K_M.gguf: 100% 4.08G/4.08G [00:37<00:00, 110MB/s]
# ./llama-2-7b-chat.Q4_K_M.gguf

# %%
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.llms import LlamaCpp

# %%
MODEL_PATH = "llama-2-7b-chat.Q4_K_M.gguf"

# %%
template = """
You are a helpful AI assistant created by Mohammed Vasim. He is an AI Engineer and developed an amazing AI model like you.
You will be asked a question, answer in a helpful manner.

Question: {question}

Answer: Let's work this out in a step by step way to be sure we have the right answer."""

prompt = PromptTemplate.from_template(template)

# %%
# Callbacks support token-wise streaming
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

# %%
# Make sure the model path is correct for your system!
# %%capture
llm = LlamaCpp(
    model_path=MODEL_PATH,
    temperature=0.75,
    max_tokens=2000,
    top_p=1,
    callback_manager=callback_manager,
    verbose=True,  # Verbose is required to pass to the callback manager
)

# %%
# prompt = """
# Question: Who are you?
# """
# llm.invoke(prompt)

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-13-5e4e4c67dc96> in <cell line: 1>()
# ----> 1 llm_chain = LLMChain(prompt=prompt, llm=llm)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, **kwargs)
#     118
#     119     def __init__(self, **kwargs: Any) -> None:
# --> 120         super().__init__(**kwargs)
#     121         self._lc_kwargs = kwargs
#     122
#
# /usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py in __init__(__pydantic_self__, **data)
#     339         values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340         if validation_error:
# --> 341             raise validation_error
#     342         try:
#     343             object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for LLMChain
# prompt
# ...
